# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !git clone https://github.com/ssut/py-hanspell
# Out:
# Cloning into 'py-hanspell'...
# remote: Enumerating objects: 110, done.
# remote: Counting objects: 100% (22/22), done.
# remote: Compressing objects: 100% (13/13), done.
# remote: Total 110 (delta 16), reused 12 (delta 9), pack-reused 88
# Receiving objects: 100% (110/110), 22.44 KiB | 522.00 KiB/s, done.
# Resolving deltas: 100% (55/55), done.

# %%
# hanspell 설치하기 위해 requests 라이브러리 설치

# %%
! pip install -U beautifulsoup4 requests
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 143.0/143.0 kB 2.7 MB/s eta 0:00:00
# ...
#   Attempting uninstall: beautifulsoup4
#     Found existing installation: beautifulsoup4 4.11.2
#     Uninstalling beautifulsoup4-4.11.2:
#       Successfully uninstalled beautifulsoup4-4.11.2
# ...

# %%
# !cd py-hanspell
# !pip3 install git+https://github.com/ssut/py-hanspell.git
# Out:
# ...
#   Cloning https://github.com/ssut/py-hanspell.git to /tmp/pip-req-build-2c5sufot
#   Running command git clone --filter=blob:none --quiet https://github.com/ssut/py-hanspell.git /tmp/pip-req-build-2c5sufot
#   Resolved https://github.com/ssut/py-hanspell.git to commit fdc6ca50c19f1c85971437a072d89d4e5ce024b8
#   Preparing metadata (setup.py) ... done
# ...
#   Created wheel for py-hanspell: filename=py_hanspell-1.1-py3-none-any.whl size=4809 sha256=2a0f3cb329b805ed833381c3d63b2ef3ca3d0b538173722cf8791199d7415590
#   Stored in directory: /tmp/pip-ephem-wheel-cache-3l7syxoc/wheels/2e/43/cc/753c9e1d91affb9ea40e186cea5654fb9231deb454da6724e5
# Successfully built py-hanspell
# ...

# %%
from hanspell import spell_checker
import numpy as np
import pandas as pd

# %%
df_ka = pd.read_csv('/content/drive/MyDrive/final_proj/dataset/kakao_mbti.csv')
df2 = pd.read_csv('/content/drive/MyDrive/final_proj/dataset/inside_2.csv',names = ['mbti','text'])
df3 = pd.read_csv('/content/drive/MyDrive/final_proj/dataset/inside_3.csv', names = ['mbti','text'])
df4 = pd.read_csv('/content/drive/MyDrive/final_proj/dataset/inside_4.csv',names = ['mbti','text','1','2'])
df5 = pd.read_csv('/content/drive/MyDrive/final_proj/dataset/inside_5_1.csv',names = ['mbti','text'])
df6 = pd.read_csv('/content/drive/MyDrive/final_proj/dataset/inside_5_2.csv',encoding = 'cp949',names = ['mbti','text'])
df7 = pd.read_csv('/content/drive/MyDrive/final_proj/dataset/inside_6.csv', encoding = 'cp949',names = ['mbti','text'])

# %%
df_ka.head()
# Out:
#    Unnamed: 0                                      text  MBTI
# 0           0  근데 주위에서 주식으로 얼마벌었다 하는 사람 보면 진짜 대단하다 생각해요  ESTP
# 1           1              부러워 하지마세요 잃은건 말 안하고 번 것만 말해요  ENTJ
# 2           2                        진짜 좀 머리아프게 살기 싫어여   ESTP
# 3           3            그냥 인생 알차고 열심히 사는게 최고인거같아요 ㅎㅎ    ISTJ
# 4           4                               열심히 사는거 최고죠  INFP

# %%
df2.head()
# Out:
#    mbti       text
# 0   NaN        NaN
# 1  ENTJ    아 ASMR~
# 2  ISTP  이제 이분은 배우
# 3  ENTJ    배우? 어디?
# 4  ISTP   뉴욕 안 갔어요

# %%
df3.head()
# Out:
#    mbti                  text
# 0  MBTI                    대사
# 1   NaN    N방 INtuition : 직관형
# 2  ISFJ         저도 울기는 했는데 근데
# 3  ENTJ           엉? 울기는 했다고?
# 4  ISFJ  네 근데 그분들 때문에 운건 아니에요

# %%
df4.head()
# Out:
#    mbti       text   1   2
# 0  ISFP   너무 떨리는데? NaN NaN
# 1  INFP  아으 떨려 ㅎㅎㅎ NaN NaN
# 2  ISFP    무서워 사실… NaN NaN
# 3  ESFJ        살려줘 NaN NaN
# 4  ENFP     뭐가 있어? NaN NaN

# %%
df5.head()
# Out:
#    mbti                 text
# 0  ESTP  아 오늘 불호 하나 있을 거 같은데
# 1  ENFJ               에이 설마~
# 2  ENTP                  우와~
# 3  ESFJ                  우와!
# 4  ENFP                   왜?

# %%
df6.head()
# Out:
#    mbti                                             text
# 0  ESTP             여기 와서 다른 사람들과 얘기할 때도 큰 영향이 없었던 것 같아요
# 1  ESTP      저는 다른 사람들한테 어떤 영향을 주었을 진 모르겠지만 다른 사람들의 영향..
# 2  ESTP                  행동이나 이런 말투들이 저한테는 큰 영향은 없었어요 그냥
# 3  ESTP  여기 와서 오히려 더 느꼈던 거는 아 난 정말 강한 사람이구나 나는 흔들리지 않는구나
# 4  ESTP                 라는 거를 많이 느꼈고요 어 앞으로도... 계속 살아가면서

# %%
df7.head()
# Out:
#    mbti                            text
# 0  ESFJ                     눈뽕이 너무 심하네요
# 1  ESFJ      어 진짜 오 너무 심한데? 잠깐 적응 좀 할게요
# 2  ESFJ                          평타 쳤어!
# 3  ESFJ                         비호감 없어!
# 4  ESFJ  근데 나 호감 하나 받고 싶어 나 아직 아무것도 없다고

# %%
#데이터 형식 통일 text열, mbti열 mbti는 소문자로
df_ka['mbti'] = df_ka['MBTI'].str.lower()
df_ka.drop(['MBTI','Unnamed: 0'], axis = 1, inplace = True)
df_ka.head()
# Out:
#                                        text  mbti
# 0  근데 주위에서 주식으로 얼마벌었다 하는 사람 보면 진짜 대단하다 생각해요  estp
# 1              부러워 하지마세요 잃은건 말 안하고 번 것만 말해요  entj
# 2                        진짜 좀 머리아프게 살기 싫어여   estp
# 3            그냥 인생 알차고 열심히 사는게 최고인거같아요 ㅎㅎ    istj
# 4                               열심히 사는거 최고죠  infp

# %%
df2['mbti'] = df2['mbti'].str.lower()
df3['mbti'] = df3['mbti'].str.lower()
df4['mbti'] = df4['mbti'].str.lower()
df5['mbti'] = df5['mbti'].str.lower()
df6['mbti'] = df6['mbti'].str.lower()
df7['mbti'] = df7['mbti'].str.lower()

# %%
df2 = df2[['text','mbti']]
df3 = df3[['text','mbti']]
df4 = df4[['text','mbti']]
df5 = df5[['text','mbti']]
df6 = df6[['text','mbti']]
df7 = df7[['text','mbti']]

# %%
df2.head()
# Out:
#         text  mbti
# 0        NaN   NaN
# 1    아 ASMR~  entj
# 2  이제 이분은 배우  istp
# 3    배우? 어디?  entj
# 4   뉴욕 안 갔어요  istp

# %%
df3.head()
# Out:
#                    text  mbti
# 0                    대사  mbti
# 1    N방 INtuition : 직관형   NaN
# 2         저도 울기는 했는데 근데  isfj
# 3           엉? 울기는 했다고?  entj
# 4  네 근데 그분들 때문에 운건 아니에요  isfj

# %%
df4.head()
# Out:
#         text  mbti
# 0   너무 떨리는데?  isfp
# 1  아으 떨려 ㅎㅎㅎ  infp
# 2    무서워 사실…  isfp
# 3        살려줘  esfj
# 4     뭐가 있어?  enfp

# %%
df5.head()
# Out:
#                   text  mbti
# 0  아 오늘 불호 하나 있을 거 같은데  estp
# 1               에이 설마~  enfj
# 2                  우와~  entp
# 3                  우와!  esfj
# 4                   왜?  enfp

# %%
df6.head()
# Out:
#                                               text  mbti
# 0             여기 와서 다른 사람들과 얘기할 때도 큰 영향이 없었던 것 같아요  estp
# 1      저는 다른 사람들한테 어떤 영향을 주었을 진 모르겠지만 다른 사람들의 영향..  estp
# 2                  행동이나 이런 말투들이 저한테는 큰 영향은 없었어요 그냥  estp
# 3  여기 와서 오히려 더 느꼈던 거는 아 난 정말 강한 사람이구나 나는 흔들리지 않는구나  estp
# 4                 라는 거를 많이 느꼈고요 어 앞으로도... 계속 살아가면서  estp

# %%
df7.head()
# Out:
#                              text  mbti
# 0                     눈뽕이 너무 심하네요  esfj
# 1      어 진짜 오 너무 심한데? 잠깐 적응 좀 할게요  esfj
# 2                          평타 쳤어!  esfj
# 3                         비호감 없어!  esfj
# 4  근데 나 호감 하나 받고 싶어 나 아직 아무것도 없다고  esfj

# %%
#데이터 병합
df_all = pd.concat([df_ka,df2,df3,df4,df5,df6,df7])

# %%
df_all.head()
# Out:
#                                        text  mbti
# 0  근데 주위에서 주식으로 얼마벌었다 하는 사람 보면 진짜 대단하다 생각해요  estp
# 1              부러워 하지마세요 잃은건 말 안하고 번 것만 말해요  entj
# 2                        진짜 좀 머리아프게 살기 싫어여   estp
# 3            그냥 인생 알차고 열심히 사는게 최고인거같아요 ㅎㅎ    istj
# 4                               열심히 사는거 최고죠  infp

# %%
df_all.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 5300 entries, 0 to 1174
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   text    4631 non-null   object
#  1   mbti    4592 non-null   object
# dtypes: object(2)
# memory usage: 124.2+ KB

# %%
#하나라도 결측치 있는 행 제거
df_all.dropna(subset = ['mbti','text'], inplace = True)

# %%
df_all.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 4592 entries, 0 to 1174
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   text    4592 non-null   object
#  1   mbti    4592 non-null   object
# dtypes: object(2)
# memory usage: 107.6+ KB

# %%
df_all['mbti'].value_counts()
# Out:
# entj     453
# istp     431
# enfp     379
# intp     344
# isfp     324
# isfj     319
# esfj     301
# entp     271
# estp     270
# esfp     265
# estj     263
# istj     211
# enfj     199
# infp     195
# intj     183
# infj     182
# mbti       1
# infp       1
# Name: mbti, dtype: int64

# %%
df_all[df_all['mbti']=='mbti']
# Out:
#   text  mbti
# 0   대사  mbti

# %%
idx = df_all[df_all['mbti']=='mbti'].index
df_all.drop(idx , inplace=True)

# %%
#글자 수 제한
df_all['text_len'] = df_all['text'].apply(len)

# %%
df_all.head()
# Out:
#                              text  mbti  text_len
# 1    부러워 하지마세요 잃은건 말 안하고 번 것만 말해요  entj        28
# 2              진짜 좀 머리아프게 살기 싫어여   estp        18
# 3  그냥 인생 알차고 열심히 사는게 최고인거같아요 ㅎㅎ    istj        30
# 4                     열심히 사는거 최고죠  infp        11
# 5        어쩔땐 태어나서 사는구나 이 생각도 했어여   estp        24

# %%
df_all = df_all[df_all['text_len']>=8]

# %%
df_all.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 3638 entries, 1 to 1173
# Data columns (total 3 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   text      3638 non-null   object
#  1   mbti      3638 non-null   object
#  2   text_len  3638 non-null   int64
# dtypes: int64(1), object(2)
# memory usage: 113.7+ KB

# %%
df_all[df_all['text_len']>=512].count()
# Out:
# text        0
# mbti        0
# text_len    0
# dtype: int64

# %%
df_all['mbti'].value_counts()
# Out:
# entj    392
# istp    331
# enfp    274
# intp    267
# isfj    263
# isfp    253
# esfj    230
# entp    213
# estj    212
# esfp    210
# estp    206
# istj    170
# enfj    159
# intj    156
# infp    155
# infj    147
# Name: mbti, dtype: int64

# %%
df_all['mbti'].nunique()
# Out:
# 16

# %%
df_all = df_all[['text','mbti']]

# %%
df_all.head()
# Out:
#                              text  mbti
# 1    부러워 하지마세요 잃은건 말 안하고 번 것만 말해요  entj
# 2              진짜 좀 머리아프게 살기 싫어여   estp
# 3  그냥 인생 알차고 열심히 사는게 최고인거같아요 ㅎㅎ    istj
# 4                     열심히 사는거 최고죠  infp
# 5        어쩔땐 태어나서 사는구나 이 생각도 했어여   estp

# %%
df_all.iloc[1,0]
# Out:
# '진짜 좀 머리아프게 살기 싫어여 '

# %%
#맞춤법 교정
#from hanspell import spell_checker
#result = spell_checker.check(u'외 않되')
#result.as_dict()
#에러 수정 어려움
#https://github.com/ssut/py-hanspell/issues/41

# %%
import matplotlib.pyplot as plt
import seaborn as sns

import warnings
warnings.filterwarnings('ignore')

# %%
mbti_cnt = pd.DataFrame(df_all['mbti'].value_counts())

# %%
mbti_cnt
# Out:
#       mbti
# entj   392
# istp   331
# enfp   274
# intp   267
# isfj   263
# isfp   253
# esfj   230
# entp   213
# estj   212
# esfp   210
# estp   206
# istj   170
# enfj   159
# intj   156
# infp   155
# infj   147

# %%
plt.figure(figsize=(12,5))
plt.bar(mbti_cnt.index, mbti_cnt['mbti'])
plt.title('Distribution of Classes')
plt.show()

# %%
df_all['ie'] = df_all['mbti'].str[0]
df_all['ns'] = df_all['mbti'].str[1]
df_all['ft'] = df_all['mbti'].str[2]
df_all['pj'] = df_all['mbti'].str[3]

# %%
df_all.head()
# Out:
#                              text  mbti ie ns ft pj
# 1    부러워 하지마세요 잃은건 말 안하고 번 것만 말해요  entj  e  n  t  j
# 2              진짜 좀 머리아프게 살기 싫어여   estp  e  s  t  p
# 3  그냥 인생 알차고 열심히 사는게 최고인거같아요 ㅎㅎ    istj  i  s  t  j
# 4                     열심히 사는거 최고죠  infp  i  n  f  p
# 5        어쩔땐 태어나서 사는구나 이 생각도 했어여   estp  e  s  t  p

# %%
mbti_cnt_ie = pd.DataFrame(df_all['ie'].value_counts())
mbti_cnt_ns = pd.DataFrame(df_all['ns'].value_counts())
mbti_cnt_ft = pd.DataFrame(df_all['ft'].value_counts())
mbti_cnt_pj = pd.DataFrame(df_all['pj'].value_counts())

# %%
mbti_cnt_ie
# Out:
#      ie
# e  1896
# i  1742

# %%
fig, axes = plt.subplots(2, 2, figsize=(8, 8))

axes[0, 0].set_title("IE Distribution", fontsize=16)
axes[0, 1].set_title("NS Distribution", fontsize=16)
axes[1, 0].set_title("FT Distribution", fontsize=16)
axes[1, 1].set_title("PJ Distribution", fontsize=16)

axes[0,0].bar(mbti_cnt_ie.index, mbti_cnt_ie['ie'])
axes[0,1].bar(mbti_cnt_ns.index, mbti_cnt_ns['ns'])
axes[1,0].bar(mbti_cnt_ft.index, mbti_cnt_ft['ft'])
axes[1,1].bar(mbti_cnt_pj.index, mbti_cnt_pj['pj'])
# Out:
# <BarContainer object of 2 artists>

# %%
df_all.to_csv('/content/drive/MyDrive/final_proj/dataset/kakao_youtube_text.csv')
