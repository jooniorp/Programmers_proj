# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd
import numpy as np

# %%
df1 = pd.read_csv("/content/drive/MyDrive/MBTI_ing.csv",index_col=0)

# %%
df1.head()
# Out:
#                                                 text  mbti
# 0  님들저 재검사했어요 E랑I있잖아요 I 49퍼 E 51퍼 N랑S S 45퍼 N 55퍼...  esfj
# 1                              @토니 INTP공지 한 번만 읽어주세요  entp
# 2                                    차라리 외우기만 하라하지..  isfp
# 3                                          깜지까지 어케해ㅠ  isfp
# 4                      아니 키키님이랑 감자님은 누가이어줘서 결혼까지했어요?  esfj

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 55213 entries, 0 to 55212
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   text    55213 non-null  object
#  1   mbti    55213 non-null  object
# dtypes: object(2)
# memory usage: 1.3+ MB

# %%
idx1 = df1[df1['text'].str.contains('공읽')].index
df1.iloc[idx1]
# Out:
#                              text  mbti
# 23                 @응이 / estp공읽닉변  istj
# 206           @흐힝/entp23분까지 공읽 닉변  isfp
# 208               23분까지 공읽 닉변부탁해용  isfp
# 265    @Nm / istp11분까지 공읽 닉변 해주세요  entp
# 358    @이정현 / entp32분까지 공읽닉변 해주세요  entp
# ...                           ...   ...
# 41031                  공읽..하고잇슘ㄴ다  estp
# 41069               어서와 공읽 닉변 부탁해  infj
# 41071            @INFP 차카공읽 닉변 ㄱㄱ  infj
# 47885                 공읽하고 닉변했습니다  infj
# 48958                    공읽 하ㅏㅏ셔요  isfp
#
# [472 rows x 2 columns]

# %%
df1 = df1.drop(idx1).reset_index(drop=True)
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 54741 entries, 0 to 54740
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   text    54741 non-null  object
#  1   mbti    54741 non-null  object
# dtypes: object(2)
# memory usage: 855.5+ KB

# %%
idx2 = df1[df1['text'].str.contains('닉변')].index
df1.iloc[idx2]
# Out:
#                                                     text  mbti
# 1155                                   @스타일테러범¹⁰ㄴ닉변 해주시죠  intp
# 1253                                       @핑크 닉변 부탁드립니다  entp
# 1743   모르겠어여!.! 이제 막 들어와서 닉변경 신청하느라요 ㅋㅋ꙼̈ㅋ̆̎ㅋ̊̈ㅋ꙼̈ㅋ̆̎...  enfp
# 3554                                          닉변 부탁드립니다?  enfp
# 3626                       @헬창이 / ENFP닉변 하셨으면 공지 읽어주세요:)  entp
# ...                                                  ...   ...
# 54383                                  닉변 고맙습니다 암튼 환영합니다  estj
# 54488                                  @entp 따봉상혁 닉변해주세요  estj
# 54521                                  @이니 ENTP 닉변 부탁할게요  estj
# 54652                                @ENTP빠바바밤 닉변 부탁드립니다  estj
# 54711                                         네 닉변부탁드릴게용  entp
#
# [153 rows x 2 columns]

# %%
df1 = df1.drop(idx2).reset_index(drop=True)
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 54588 entries, 0 to 54587
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   text    54588 non-null  object
#  1   mbti    54588 non-null  object
# dtypes: object(2)
# memory usage: 853.1+ KB

# %%
idx3 = df1[df1['text'].str.contains('@')].index
df1.iloc[idx3]
# Out:
#                                            text  mbti
# 1                         @토니 INTP공지 한 번만 읽어주세요  entp
# 23                        @응이 / estp공지한번만 읽어주세요  entp
# 126                                 @카크쿠/ESTJ-T  istj
# 143    @카크쿠/ESTJ-T모의고사 문장 꼴랑 23줄밖에 안되니까 외워줄수있어?  entp
# 205                       @흐힝/entp공지 한 번만 읽어주세요  entp
# ...                                         ...   ...
# 54393                  @ENTP 라따뚜이(지원) 희망진로가 뭐에요  estj
# 54457                      @INTP 제이/07/여 잘부탁드려요  estj
# 54469               @반려INFP 4살9w1@ENTP 라따뚜이(지원)  istp
# 54489                            @ENTP 라따뚜이(지원)  isfj
# 54503                     @ENTP빠바바밤 우리 재미있게 놉시다  estj
#
# [928 rows x 2 columns]

# %%
df1 = df1.drop(idx3).reset_index(drop=True)
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 53660 entries, 0 to 53659
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   text    53660 non-null  object
#  1   mbti    53660 non-null  object
# dtypes: object(2)
# memory usage: 838.6+ KB

# %%
idx4 = df1[df1['text'].str.contains('공지')].index
df1.iloc[idx4]
# Out:
#                        text  mbti
# 1113             공지 읽었습니다 🥰  infj
# 1195   안녕하세요 공지 한번만 읽어주세요!   istp
# 1222               공지 읽었습니다  istp
# 1272              공지를 물어뜯네?  istj
# 1297       굳 공지 한번만 읽어주세요!   istp
# ...                     ...   ...
# 53448     공지도 읽어주시면 감사하겠습니다  estj
# 53466             인공지능 수학인가  entp
# 53559              공지 읽어주세용  entp
# 53574              공지 읽어주세용  entp
# 53630            공지 읽어주세오ㅡㅇ  entp
#
# [237 rows x 2 columns]

# %%
df1 = df1.drop(idx4).reset_index(drop=True)
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 53423 entries, 0 to 53422
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   text    53423 non-null  object
#  1   mbti    53423 non-null  object
# dtypes: object(2)
# memory usage: 834.9+ KB

# %%
df2 = pd.read_csv("/content/drive/MyDrive/df_text_cleaned_na.csv")
df2.head()
# Out:
#                                                 text  mbti
# 0                                애칭 어떻게 부르셨는지 알려주세요   intj
# 1  나만 남자친구랑 데이트 생각하는 거 같고 어찌나 서운하던지 근데 또 집에 가면 편해...  infp
# 2  istj와 isfj는 알파벳 한 끗 차이인데 istj이시면서 t와 f가 거의 비슷한...  entp
# 3                          잇디 제분들 직장에서 수다떨기 좋아하시나요?   isfj
# 4  estj 남 entj여 인 분들 연애 어떻게 하시고 계시나요? 사귄 지 얼마 안 됐...  entj

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 122080 entries, 0 to 122079
# Data columns (total 2 columns):
#  #   Column  Non-Null Count   Dtype
# ---  ------  --------------   -----
#  0   text    122080 non-null  object
#  1   mbti    122080 non-null  object
# dtypes: object(2)
# memory usage: 1.9+ MB

# %%
df3 = pd.read_csv("/content/drive/MyDrive/kakao_youtube_text.csv", index_col=0)
df3.head()
# Out:
#                                        text  mbti
# 0  근데 주위에서 주식으로 얼마벌었다 하는 사람 보면 진짜 대단하다 생각해요  estp
# 1              부러워 하지마세요 잃은건 말 안하고 번 것만 말해요  entj
# 2                        진짜 좀 머리아프게 살기 싫어여   estp
# 3            그냥 인생 알차고 열심히 사는게 최고인거같아요 ㅎㅎ    istj
# 4                               열심히 사는거 최고죠  infp

# %%
df3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 4231 entries, 0 to 5383
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   text    4231 non-null   object
#  1   mbti    4231 non-null   object
# dtypes: object(2)
# memory usage: 99.2+ KB

# %%
df_all = pd.concat([df1,df2,df3])
df_all.head()
# Out:
#                                                 text  mbti
# 0  님들저 재검사했어요 E랑I있잖아요 I 49퍼 E 51퍼 N랑S S 45퍼 N 55퍼...  esfj
# 1                                    차라리 외우기만 하라하지..  isfp
# 2                                          깜지까지 어케해ㅠ  isfp
# 3                      아니 키키님이랑 감자님은 누가이어줘서 결혼까지했어요?  esfj
# 4                                        ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ  entp

# %%
df_all.duplicated(subset=['text']).sum()
# Out:
# 3465

# %%
df_all.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 179734 entries, 0 to 5383
# Data columns (total 2 columns):
#  #   Column  Non-Null Count   Dtype
# ---  ------  --------------   -----
#  0   text    179734 non-null  object
#  1   mbti    179734 non-null  object
# dtypes: object(2)
# memory usage: 4.1+ MB

# %%
df_all = df_all.drop_duplicates(subset='text')

# %%
df_all.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 176269 entries, 0 to 5383
# Data columns (total 2 columns):
#  #   Column  Non-Null Count   Dtype
# ---  ------  --------------   -----
#  0   text    176269 non-null  object
#  1   mbti    176269 non-null  object
# dtypes: object(2)
# memory usage: 4.0+ MB

# %%
df_all=df_all.dropna()

# %%
df_all.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 176269 entries, 0 to 5383
# Data columns (total 2 columns):
#  #   Column  Non-Null Count   Dtype
# ---  ------  --------------   -----
#  0   text    176269 non-null  object
#  1   mbti    176269 non-null  object
# dtypes: object(2)
# memory usage: 4.0+ MB

# %%
df_all.to_csv("/content/drive/MyDrive/total_dataset.csv")
