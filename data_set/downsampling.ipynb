# %%
import pandas as pd

# %%
df=pd.read_csv('mbti_100_4.csv',encoding='UTF-8')

# %%
df.head(5)
# Out:
#    Unnamed: 0.1  Unnamed: 0  \
# 0             0           0
# 1             1           1
# 2             2           2
# 3             3           3
# 4             4           4
#
#                                                 text  mbti ie ns ft pj
# 0  궁금해요   사귄 지 얼마 안 됐고 섬 탈 때도 그냥 용건만 연락하는 편이길래 그러...  infp  i  n  f  p
# 1  알려줘야 된다고 생각하세요? 아니면 굳이 필요 없다고 생각하세요? 자잘한 일상 공유...  infp  i  n  f  p
# 2  istj와 isfj는 알파벳 한 끗 차이인데 istj이시면서 t와 f가 거의 비슷한...  infp  i  n  f  p
# 3  잇디 제분들 직장에서 수다떨기 좋아하시나요?  estj 남 entj여 인 분들 연애...  infp  i  n  f  p
# 4  뭔가 잘 될 것 같긴 한데 또 길어지는 백수생활 합리화도 하고요...ㅎㅎ ... 지...  infp  i  n  f  p

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 24269 entries, 0 to 24268
# Data columns (total 8 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Unnamed: 0.1  24269 non-null  int64
#  1   Unnamed: 0    24269 non-null  int64
#  2   text          24269 non-null  object
#  3   mbti          24269 non-null  object
#  4   ie            24269 non-null  object
#  5   ns            24269 non-null  object
#  6   ft            24269 non-null  object
#  7   pj            24269 non-null  object
# dtypes: int64(2), object(6)
# memory usage: 1.5+ MB

# %%
df['text'].str.len().value_counts()
# Out:
# text
# 103    406
# 100    401
# 104    375
# 101    375
# 107    373
#       ...
# 412      1
# 458      1
# 440      1
# 447      1
# 94       1
# Name: count, Length: 404, dtype: int64

# %%
df['text'].count()
# Out:
# 24269

# %%
df1=df['ie']=="i"
df2=df['ie']=="e"
df3=df['ns']=="n"
df4=df['ns']=="s"
df5=df['ft']=="f"
df6=df['ft']=="t"
df7=df['pj']=="p"
df8=df['pj']=="j"

# %%
df_i=df[df1]
df_e=df[df2]
df_n=df[df3]
df_s=df[df4]
df_f=df[df5]
df_t=df[df6]
df_p=df[df7]
df_j=df[df8]

# %%
df_i.head(5)
# Out:
#    Unnamed: 0.1  Unnamed: 0  \
# 0             0           0
# 1             1           1
# 2             2           2
# 3             3           3
# 4             4           4
#
#                                                 text  mbti ie ns ft pj
# 0  궁금해요   사귄 지 얼마 안 됐고 섬 탈 때도 그냥 용건만 연락하는 편이길래 그러...  infp  i  n  f  p
# 1  알려줘야 된다고 생각하세요? 아니면 굳이 필요 없다고 생각하세요? 자잘한 일상 공유...  infp  i  n  f  p
# 2  istj와 isfj는 알파벳 한 끗 차이인데 istj이시면서 t와 f가 거의 비슷한...  infp  i  n  f  p
# 3  잇디 제분들 직장에서 수다떨기 좋아하시나요?  estj 남 entj여 인 분들 연애...  infp  i  n  f  p
# 4  뭔가 잘 될 것 같긴 한데 또 길어지는 백수생활 합리화도 하고요...ㅎㅎ ... 지...  infp  i  n  f  p

# %%
df_i['text'].count(), df_e['text'].count(),df_n['text'].count(),df_s['text'].count(),df_f['text'].count(),df_t['text'].count(),df_p['text'].count(),df_j['text'].count()
# Out:
# (16466, 7803, 15470, 8799, 11799, 12470, 14170, 10099)

# %%
df_ie=df.drop(['Unnamed: 0.1','Unnamed: 0','ns','ft','pj'],axis=1)

# %%
df_ie.head(5)
# Out:
#                                                 text  mbti ie
# 0  궁금해요   사귄 지 얼마 안 됐고 섬 탈 때도 그냥 용건만 연락하는 편이길래 그러...  infp  i
# 1  알려줘야 된다고 생각하세요? 아니면 굳이 필요 없다고 생각하세요? 자잘한 일상 공유...  infp  i
# 2  istj와 isfj는 알파벳 한 끗 차이인데 istj이시면서 t와 f가 거의 비슷한...  infp  i
# 3  잇디 제분들 직장에서 수다떨기 좋아하시나요?  estj 남 entj여 인 분들 연애...  infp  i
# 4  뭔가 잘 될 것 같긴 한데 또 길어지는 백수생활 합리화도 하고요...ㅎㅎ ... 지...  infp  i

# %%
df_ie['text'].count()
# Out:
# 24269

# %%
df_ie[(df_ie['ie']=='i')&(df_ie['text'].str.len()<135)].count()
# Out:
# text    8197
# mbti    8197
# ie      8197
# dtype: int64

# %%
df_ie.drop(df_ie[(df_ie['ie']=='i')&(df_ie['text'].str.len()<130)].index, inplace=True)

# %%
df_ie['text'].count()
# Out:
# 16921

# %%
df_ie_1=df_ie['ie']=="i"
df_ie_2=df_ie['ie']=="e"

# %%
df_i=df_ie[df_ie_1]
df_e=df_ie[df_ie_2]

# %%
df_i['text'].count(), df_e['text'].count()
# Out:
# (9118, 7803)

# %%
df_ie.to_csv('mbti_100_4_ie.csv')

# %%
df_ns=df.drop(['Unnamed: 0.1','Unnamed: 0','ie','ft','pj'],axis=1)

# %%
df_ns.head(5)
# Out:
#                                                 text  mbti ns
# 0  궁금해요   사귄 지 얼마 안 됐고 섬 탈 때도 그냥 용건만 연락하는 편이길래 그러...  infp  n
# 1  알려줘야 된다고 생각하세요? 아니면 굳이 필요 없다고 생각하세요? 자잘한 일상 공유...  infp  n
# 2  istj와 isfj는 알파벳 한 끗 차이인데 istj이시면서 t와 f가 거의 비슷한...  infp  n
# 3  잇디 제분들 직장에서 수다떨기 좋아하시나요?  estj 남 entj여 인 분들 연애...  infp  n
# 4  뭔가 잘 될 것 같긴 한데 또 길어지는 백수생활 합리화도 하고요...ㅎㅎ ... 지...  infp  n

# %%
df_ns[(df_ns['ns']=='n')&(df_ns['text'].str.len()<126)].count()
# Out:
# text    6180
# mbti    6180
# ns      6180
# dtype: int64

# %%
df_ns.drop(df_ns[(df_ns['ns']=='n')&(df_ns['text'].str.len()<126)].index, inplace=True)

# %%
df_ns['text'].count()
# Out:
# 18089

# %%
df_ns.to_csv('mbti_100_4_ns.csv')
